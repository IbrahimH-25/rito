# %%
#from json import requests

import json
import requests
import sqlite3 as sql
from pandas import read_sql,DataFrame
response = requests.get("https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/person25square?api_key=RGAPI-be0a081f-97be-4153-bf50-a0908678e477")

response.json()
#response.text
# Out:
# {'id': 'qdmmYZfo1uXt8hXgu1MpP-UsTNqfzGMuF27QqTGG9myXV-g',
#  'accountId': 'a6Af4p-dpg4HBHo4QbBGRvR9H73TQ-DxD0mAbTbWiH_bK0H5BydjrlWR',
#  'puuid': '6eaUjAR5H818B5XRQedHS6s2520Jc-2ftftg-BCaluuCMxnberP39NO9WNK0mimDV34LcOrz1PnZZw',
#  'name': 'Person25square',
#  'profileIconId': 980,
#  'revisionDate': 1665204158000,
#  'summonerLevel': 320}

# %%
class rito:
    apiKey =  'RGAPI-be0a081f-97be-4153-bf50-a0908678e477'

    def __innit__(self):
        self.apiKey = self.apiKey

    def puuidToID(self,puuid):
        inputString = "https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-puuid/%s?api_key=%s"%(puuid,self.apiKey)
        #print(inputString)
        response = requests.get(inputString)
        try:
            return  response.json()['id']
        except:
            print(response.json())
            return 0
    
    def getPuuidsFromChallanges(self,challangeId = '402401',chLevel = "MASTER"):
        response = requests.get('https://na1.api.riotgames.com/lol/challenges/v1/challenges/%s/leaderboards/by-level/%s?api_key=%s'%(challangeId,chLevel,self.apiKey))
        jsonque = response.json()
        puuidList = []
        for que in jsonque:
            puuidList.append(que['puuid'])
        return puuidList

    def getChampMasteries(self,sumId):
        response = requests.get("https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/%s?api_key=%s"%(sumId,self.apiKey))
        #print(response.text)
        champMasterMap = response.json()
        return champMasterMap
    
    def readSql(self,table,con):
        readDf = read_sql(table,con)
    
    def toSql(self,df,table,con):
        df.to_sql(table,con,if_exists = 'append')

    def makeDfAndName(self,champList,champSize):
        tableName = champList[0]
        champNewList = [1:champSize-1]
# Out:
#   Input In [8]
#     def
#         ^
# SyntaxError: invalid syntax

# %%
#apikey = 'RGAPI-be0a081f-97be-4153-bf50-a0908678e477'
con = sql.connect("champsimDB.db")
rit = rito()
rit.puuidToID('6eaUjAR5H818B5XRQedHS6s2520Jc-2ftftg-BCaluuCMxnberP39NO9WNK0mimDV34LcOrz1PnZZw')
puudlist = rit.getPuuidsFromChallanges()
#for pud in puudlist:
sumId = rit.puuidToID(puudlist[0])
CMMap = rit.getChampMasteries(sumId)

con.close()

# %%
r
for entry in r
    print(e)
# Out:
# [{'championId': 64,
#   'championLevel': 7,
#   'championPoints': 330183,
#   'lastPlayTime': 1663564693000,
#   'championPointsSinceLastLevel': 308583,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'gsKWTPu-AikFhFU2LaOApQ6LXGg89QFgeqgWJHXFbE9qTEU'},
#  {'championId': 104,
#   'championLevel': 7,
#   'championPoints': 262644,
#   'lastPlayTime': 1665439351000,
#   'championPointsSinceLastLevel': 241044,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'gsKWTPu-AikFhFU2LaOApQ6LXGg89QFgeqgWJHXFbE9qTEU'},
#  {'championId': 234,
#   'championLevel': 7,
#   'championPoints': 148142,
#   'lastPlayTime': 1665434905000,
#   'championPointsSinceLastLevel': 126542,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'gsKWTPu-AikFhFU2LaOApQ6LXGg89QFgeqgWJHXFbE9qTEU'},
#  {'championId': 92,
#   'championLevel': 7,
# ...

# %%
#​https://127.0.0.1:2999/liveclientdata/playerlist
response = requests.get("https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/AY_H-P5YIfGzYI3kTk0MDCJR8Qsi2ilLC-cOmvsXItiMhWA?api_key=RGAPI-54738f64-0b97-445c-a5dd-b6ff0a3a0663")


#print(response.text)
r = response.json()
r
# Out:
# {'status': {'message': 'Forbidden', 'status_code': 403}}

# %%
listWebsite = requests.get("https://www.leagueofgraphs.com/rankings/summoners")

from bs4 import BeautifulSoup

htmldoc = listWebsite.text

#with open("https://www.leagueofgraphs.com/rankings/summoners") as fp:
soup = BeautifulSoup(htmldoc,"html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,500,700" media="none" onload="this.media='all'" rel="stylesheet" type="text/css"/> <link href="//lolg-cdn.porofessor.gg/style.css?v=1665243271" rel="stylesheet" type="text/css">
# <link href="//lolg-cdn.porofessor.gg/style.sprite.css?v=2fca8dfb6c0f22f6d28e3173c978826a" rel="stylesheet" type="text/css"/>
# <script src="//lolg-cdn.porofessor.gg/jquery.js?v=3"></script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="content-language"/>
# ...
